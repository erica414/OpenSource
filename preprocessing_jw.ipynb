# %% [markdown]
# 키워드 추출 모듈

# %%
import pandas as pd

df = pd.read_csv("C:/Users/jw/Desktop/4학년/4-2/OSS/국밥집 크롤링 데이터/porksoup_google_review(hapcheon).csv")
df
# Out:
#                    작성자         날짜     평점  \
# 0     Woo Lee (iWorks)       1주 전  별표 3개
# 1                  김정훈  수정일: 1주 전  별표 4개
# 2                  신찰스  수정일: 1주 전  별표 5개
# 3                 とっきー       1주 전  별표 5개
# 4                  주재형       1주 전  별표 3개
# ...                ...        ...    ...
# 2995               김남훈       5년 전  별표 5개
# 2996           KM Shim       5년 전  별표 5개
# 2997               임댓빵       5년 전  별표 1개
# 2998               강태호       5년 전  별표 3개
# 2999              커엽호야       5년 전  별표 5개
#
#                                                      리뷰
# 0                                            달달한. 김치찌게.
# 1                                                  국밥맛집
# 2                         여기야 뭐 말이 필요가 없는곳입니다. 돼지국밥 탑티어
# 3     마늘 듬뿍 맛있는\n셀프 바에서 반찬을 찍는 것은 기쁘다.\n이번에는 우동으로 만들...
# 4                                                   NaN
# ...                                                 ...
# 2995                                                NaN
# 2996                                               아주좋음
# 2997                                      부산돼지국밥중 젤 맛없음
# 2998                                                NaN
# 2999  특징이 고기가 비계가 없는 편이며 마늘이 듬뿍 들어있습니다 셀프코너에 밥과 반찬이 ...
#
# [3000 rows x 4 columns]

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\jw\anaconda3\envs\lwb_38\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\jw\anaconda3\envs\lwb_38\lib\site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\jw\anaconda3\envs\lwb_38\lib\site-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\jw\anaconda3\envs\lwb_38\lib\site-packages (from konlpy) (1.24.4)
# Requirement already satisfied: packaging in c:\users\jw\anaconda3\envs\lwb_38\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.1)

# %%
from konlpy.tag import Hannanum, Okt, Kkma, Komoran

tagger1 = Okt()
tagger2=Hannanum()
tagger3=Kkma()
tagger4=Komoran()

# %%
text =df['리뷰']
text
# Out:
# 0                                              달달한. 김치찌게.
# 1                                                    국밥맛집
# 2                           여기야 뭐 말이 필요가 없는곳입니다. 돼지국밥 탑티어
# 3       마늘 듬뿍 맛있는\n셀프 바에서 반찬을 찍는 것은 기쁘다.\n이번에는 우동으로 만들...
# 4                                                     NaN
#                               ...
# 2995                                                  NaN
# 2996                                                 아주좋음
# 2997                                        부산돼지국밥중 젤 맛없음
# 2998                                                  NaN
# 2999    특징이 고기가 비계가 없는 편이며 마늘이 듬뿍 들어있습니다 셀프코너에 밥과 반찬이 ...
# Name: 리뷰, Length: 3000, dtype: object

# %% [markdown]
# 한글, 영어만 포함되게

# %%
text_filtered = text.str.replace("[^a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣\s]", "", regex=True)
text_filtered = text_filtered.str.replace("\s+", " ", regex=True)
text_filtered[0]
# Out:
# '달달한 김치찌게'

# %% [markdown]
# 불용어 지정

# %%
stopwords = "돼지국밥 부산 국밥 ㅠ ㅠㅠ ㅠㅠㅠ ㅋ ㅋㅋ ㅋㅋㅋ ㅋㅋㅋㅋ ㅎ ㅎㅎ ㅎㅎㅎ 돼지국밥집 국밥집 여기 방문 정도 이곳 nan"
stopwords = stopwords.split(' ')

# %% [markdown]
# 키워드 전처리

# %%
tokenized_data_filtered2 = []

for i in text_filtered:
    temp = tagger3.nouns(str(i))
    temp =  [word for word in temp if len(word)>1] #1자리 글자 제거
'이층주차장', '주차장'], ['국물', '표현', '부족', '정도로', '도로', '진국', '돼지', '돼지국밥맛집', '집중', '최고', '오늘', '오늘부'], ['고기', '고기국밥', '먹음', '마늘', '다대기', '한번', '맛있음', '있음', '공항', '예정'], [], ['음식', '서비스'], ['공항', '유명', '가게', '도착', '시점'], [], ['정통', '한국', '음식', '만족'], [], ['수요일', '이후', '웨이팅', '주차장'], ['돼지고기', '서비스'], [], ['말레이시아', '말레이시아일간', '일간', '가족', '여행', '마음', 'ㅎ부산', '돼지', '아침', '아침시', '도착', '고기', '고기양', '돼지후지의', '지의', '육수', '우려', '사골', '사골육수', '고기육수', '맹물', '맹물맛', '모두', '인상', '김치', '새우젓', '반도', '숟가락'], ['년만', '옛날', '사람', '메뉴', '우동', '매일', '간적'], ['맑은', '국물', '돼지', '지금', '식당', '최고', '최고예', '중요', '시간', '이용', '가능', '점포'], [], [], [], [], ['보통', '사람'], [], ['당연지사', '지사', '국물', '고기'], ['가게', '유명', '유명점', '나중', '쿠파', '우마'], ['부산도착', '도착', '음식', '양이'], [], ['인상', '이전', '생각'], [], [], ['명불허전', '불허', '부산남바'], ['아침', '에어컨', '안틈', '쏘쏘', '부산사람', '사람', '사실', '어디'], ['돼지고기', '덩어리', '탕수육', '저희', '오리지널', '버전', '고기', '세트', '육수', '주문', '장아찌', '채소', '상추', '마음', '양파', '마늘', '서비스', '김치', '만큼', '리필'], [], [], ['있음', '국물', '제일', '유명', '생각', '었슴'], ['명불허전', '불허', '배신', '사상', '부근', '맛집', '생각', '가게'], ['돼지', '우동면', '동면', '특이', '정구', '정구지가', '지가', '입맛', '자극적'], [], ['호텔', '로비', '직원', '추천', '사람', '친구', '적당', '김치'], ['국물', '우동', '김치', '깍뚜기', '양파'], ['맛개인적', '개인적', '서비스', '서비스대형홀', '대형', '식당', '특유', '어수', '어수선', '입장객', '입장객수', '제한', '정리', '느낌', '가격', '가격유명', '유명', '어깨'], [], [], ['혼밥하', '사람', '응대', '음식', '마늘', '한수', '한수푼', '돼지', '생각'], ['음식', '갈비'], [], [], ['돼지고기', '생선', '냄새'], [], [], ['아세안', '아세안게임', '게임', '시기', '지인', '추천', '지금', '방문시', '가능', '개인적', '무엇', '반찬', '부추', '부추등', '무한', '무한리필', '리필', '직원', '친절', '주차', '자리'], [], ['기대', '실망', '돼지', '우동', '웨이팅', '한데', '혼자', '손님', '친절', '셀프', '셀프코너', '코너'], ['오전', '지역', '주민'], ['음식', '접수원', '영어', '손님', '친절'], ['닭고기', '마늘', '당신'], ['사진', '수백', '사람', '부담', '맛집'], ['사상', '사상역', '근처', '위치', '합천일', '천일', '돼지'], ['맛있음', '있음', '돼지', '내가', '적음', '공기', '공기밥', '셀프', '셀프바', '맑은', '맑은국물', '국물', '전부', ' ...

# %% [markdown]
# 빈도분석(탑 100)

# %%
from collections import Counter

tokens = []

for k in tokenized_data_filtered2:
    tokens.extend(k) #k 하나마다 리스트들이니까 리스트들을 하나의 리스트로 합쳐줌

num_top_tokens = 100

counted_tokens = Counter(tokens)
top_keywords = dict(counted_tokens.most_common(num_top_tokens))

print(top_keywords)

top_keywords_df = pd.DataFrame(list(top_keywords.items()), columns = ["keywords", "freq"])
