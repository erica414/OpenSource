# %% [markdown]
# 키워드 추출 모듈

# %%
import pandas as pd

df = pd.read_csv("C:/Users/PKNU/Downloads/porksoup_review_data/sura_porksoup_google_review.csv")
df
# Out:
#                작성자    날짜     평점  \
# 0              강준열  1주 전  별표 5개
# 1              황상근  4달 전  별표 4개
# 2              박병우  5달 전  별표 5개
# 3     boring idiot  8달 전  별표 5개
# 4                전  8달 전  별표 4개
# ..             ...   ...    ...
# 163    Tenspear WG  8년 전  별표 5개
# 164             우팡  8년 전  별표 4개
# 165           귤하르방  8년 전  별표 3개
# 166            장태수  8년 전  별표 3개
# 167  조광현 (rootpie)  9년 전  별표 4개
#
#                                                     리뷰
# 0                                                  NaN
# 1                                                  NaN
# 2                   서비스, 분위기 굿, 맛은 특별히 맛있다는 아니고 평균적인 맛
# 3    2025.02.10.\n오후 3시쯤 방문 했을 때 좌석 넉넉히 있었고 친절하게 자리...
# 4                                                  NaN
# ..                                                 ...
# 163                                                NaN
# 164                                                NaN
# 165                                                 무난
# 166                                               그냥저냥
# 167                             가격은 6천원 정도이고 맛은 괜찮습니다.
#
# [168 rows x 4 columns]

# %%
from konlpy.tag import Hannanum, Okt, Kkma, Komoran

tagger1 = Okt()
tagger2=Hannanum()
tagger3=Kkma()
tagger4=Komoran()

# %%
text =df['리뷰']
text
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                     서비스, 분위기 굿, 맛은 특별히 맛있다는 아니고 평균적인 맛
# 3      2025.02.10.\n오후 3시쯤 방문 했을 때 좌석 넉넉히 있었고 친절하게 자리...
# 4                                                    NaN
#                              ...
# 163                                                  NaN
# 164                                                  NaN
# 165                                                   무난
# 166                                                 그냥저냥
# 167                               가격은 6천원 정도이고 맛은 괜찮습니다.
# Name: 리뷰, Length: 168, dtype: object

# %% [markdown]
# 한글, 영어만 포함되게

# %%
text_filtered = text.str.replace("[^a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣\s]", "", regex=True)
text_filtered = text_filtered.str.replace("\s+", " ", regex=True)
text_filtered[0]
# Out:
# nan

# %% [markdown]
# 불용어 지정

# %%
stopwords = "돼지국밥 부산 국밥 ㅠ ㅠㅠ ㅠㅠㅠ ㅋ ㅋㅋ ㅋㅋㅋ ㅋㅋㅋㅋ ㅎ ㅎㅎ ㅎㅎㅎ 돼지국밥집 국밥집 여기 방문 정도 이곳 nan"
stopwords = stopwords.split(' ')

# %% [markdown]
# 키워드 전처리

# %%
tokenized_data_filtered2 = []

for i in text_filtered:
    temp = tagger3.nouns(str(i))
    temp =  [word for word in temp if len(word)>1] #1자리 글자 제거
    temp = [word for word in temp if word not in stopwords] #불용어제거
    tokenized_data_filtered2.append(temp)

print(tokenized_data_filtered2)
# Out:
# %% [markdown]
# 빈도분석(탑 100)

# %%
from collections import Counter

tokens = []

for k in tokenized_data_filtered2:
    tokens.extend(k) #k 하나마다 리스트들이니까 리스트들을 하나의 리스트로 합쳐줌

num_top_tokens = 100

counted_tokens = Counter(tokens)
top_keywords = dict(counted_tokens.most_common(num_top_tokens))

print(top_keywords)

top_keywords_df = pd.DataFrame(list(top_keywords.items()), columns = ["keywords", "freq"])
# Out:
# {'돼지': 9, '국물': 6, '깍두기': 5, '시간': 5, '친절': 4, '수라': 4, '서비스': 3, '기본': 3, '고기': 3, '양파': 3, '가격': 3, '수육': 3, '해장': 3, '다대기': 2, '가야': 2, '식사': 2, '신선': 2, '추천': 2, '반찬': 2, '요새': 2, '하나': 2, '위생': 2, '밥집': 2, '이모': 2, '내가': 2, '순대': 2, '수육백반': 2, '백반': 2, '경대': 2, '소주': 2, '대학가': 2, '영업': 2, '김치': 2, '개인적': 2, '수라돼지국밥': 2, '음식': 2, '분위기': 1, '평균적': 1, '오후': 1, '좌석': 1, '자리': 1, '안내': 1, '있지': 1, '구비': 1, '취향': 1, '만두': 1, '직원': 1, '직원분': 1, '저녁': 1, '저녁타임분': 1, '타임': 1, '기본적': 1, '고기양': 1, '부추': 1, '나머지': 1, '야채': 1, '무난': 1, '접시': 1, '부분': 1, '마늘': 1, '리필': 1, '물가': 1, '소리': 1, '주고': 1, '훈계': 1, '자주': 1, '생각': 1, '마싯': 1, '무엇': 1, '전반적': 1, '고추': 1, '보임': 1, '양념장': 1, '인분': 1, '하다': 1, '충실': 1, '차이점': 1, '참기름': 1, '고소한': 1, '뚝배기': 1, '위생적': 1, '식사시간': 1, '본인': 1, '가게': 1, '맛과': 1, '순대국밥': 1, '주변': 1, '한약재': 1, '수라국밥': 1, '발견': 1, '담엔': 1, '맛있엉': 1, '있엉': 1, '배려': 1, '수백': 1, '꿀맛': 1, '꿀맛임': 1, '가야돼지국밥': 1, '부산대': 1, '마차': 1}

# %% [markdown]
# 전처리 결과 및 top100 키워드 텍스트 파일로 저장

# %%
import os

folder_path = "C:/Users/PKNU/Desktop/preprocessing_data"
os.makedirs(folder_path, exist_ok=True)

# 전처리 결과 저장
filename1 = "sura_keyword.txt"  # 전처리 결과 저장할 파일 이름
save_path = os.path.join(folder_path, filename1)

with open(save_path, "w", encoding="utf-8") as f:
    for doc in tokenized_data_filtered2:
        line = " ".join(doc)
        f.write(line + "\n")
        
        
# top100 저장
filename2 = "sura_keyword_top100.txt"   # top100 키워드 저장할 파일 이름
save_path2 = os.path.join(folder_path, filename2)

with open(save_path2, "w", encoding="utf-8") as f:
    for word, freq in top_keywords.items():
        f.write(f"{word}: {freq}\n")
